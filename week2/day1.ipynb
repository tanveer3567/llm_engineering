# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)

# del os.environ['OPENAI_API_KEY']

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to work?
#
# Because they wanted to take their models to the next level!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one for you:
#
# **Why did the LLM engineer bring a ladder to work?**
#
# Because they kept hearing about "prompt engineering" but all their outputs were still on a lower level! 🪜
#
# ---
#
# **Bonus dad joke:**
#
# How many tokens does it take to tell a good LLM joke?
#
# *More than the context window allows.* 😅
#
# ---
#
# Keep at it! Remember: even the best LLM engineers started out thinking "temperature" was just about the weather and "hallucinations" only happened at music festivals. You're on the right path! 🚀

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Interpretation:
# - Each volume has pages total thickness 2 cm = 20 mm.
# - Each cover thickness = 2 mm.
#
# Stack arrangement when the volumes stand side by side on a shelf (ordered: first volume, then second), with covers and pages in standard book layout.
#
# Per typical bookshelf layout (front covers facing you):
# - The order from left to right is: front cover of Volume 1, pages of Volume 1, back cover of Volume 1, front cover of Volume 2, pages of Volume 2, back cover of Volume 2.
# - A worm gnawing perpendicularly to the pages from the first page of the first volume to the last page of the second volume travels through the material between those pages along a straight line.
#
# Key observation:
# - The first page of Volume 1 is immediately after the front cover of Volume 1.
# - The last page of Volume 2 is immediately before the back cover of Volume 2.
#
# Distance through material from first page of V1 to last page of V2 includes:
# 1) through the front cover of Volume 1 (2 mm)
# 2) through the entire pages of Volume 1 (20 mm)
# 3) through the back cover of Volume 1 (2 mm)
# 4) through the front cover of Volume 2 (2 mm)
# 5) through the entire pages of Volume 2 (20 mm)
#
# But the worm starts at the first page of V1 and ends at the last page of V2. It does not need to pass through the front cover of V1 (since it starts at the first page, which is just after the front cover). It ends at the last page of V2, which is just before the back cover, so it does not pass through the back cover of V2.
#
# Thus the distance equals:
# - through the front cover of V1? No.
# - through the pages of V1: 20 mm
# - through the back cover of V1: 2 mm
# - through the front cover of V2: 2 mm
# - through the pages of V2: 20 mm
#
# Total = 20 + 2 + 2 + 20 = 44 mm = 4.4 cm.
#
# Answer: 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and what the worm actually gnaws through.
#
# **Key insight: How books sit on a shelf**
#
# When two volumes stand side by side on a bookshelf in reading order (Volume 1, then Volume 2), they look like this from the perspective of someone facing the shelf:
#
# - **Volume 1** (on the left):
#   - Back cover (left side)
#   - Pages (with page 1 on the RIGHT side of the book, last page on the LEFT)
#   - Front cover (right side)
#
# - **Volume 2** (on the right):
#   - Back cover (left side)
#   - Pages (with page 1 on the RIGHT side of the book, last page on the LEFT)
#   - Front cover (right side)
#
# **Important:** When a book is closed and standing upright on a shelf:
# - The first page is on the INNER right side (near the spine on the right when facing it)
# - The last page is on the INNER left side (near the spine on the left when facing it)
#
# **What the worm gnaws through:**
#
# Starting point: First page of Volume 1 = rightmost part of Volume 1's pages
# Ending point: Last page of Volume 2 = leftmost part of Volume 2's pages
#
# The worm's path goes from right side of Volume 1 to left side of Volume 2:
#
# 1. Front cover of Volume 1: **2 mm**
# 2. ALL pages of Volume 2: **2 cm = 20 mm**
# 3. Back cover of Volume 2: **2 mm**
#
# Wait, let me reconsider. The worm goes from the first page of Volume 1 to the last page of Volume 2:
#
# - From the first page of Volume 1, the worm exits through the front cover of Volume 1
# - Crosses the gap (if any - typically none)
# - Enters Volume 2 through its back cover
# - Goes through all the pages of Volume 2
# - Reaches the last page of Volume 2
#
# So the path includes:
# - Front cover of Volume 1: 2 mm
# - Back cover of Volume 2: 2 mm
# - All pages of Volume 2: 20 mm
#
# **Total distance: 2 + 2 + 20 = 24 mm = 2.4 cm**
#
# The answer is **2.4 cm** (or **24 mm**).

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: On a shelf with spines facing out, the first page of volume 1 lies just inside its front cover (the side facing volume 2), and the last page of volume 2 lies just inside its back cover (the side facing volume 1). So the worm passes only through the two covers between the books: 2 mm + 2 mm = 4 mm.

# %%
# Use model ID only (no ":generateContent" — that's for Google's native API)
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic trick question! The key is how books are arranged on a shelf and where the "first page" and "last page" are located.
#
# Imagine the books on the shelf:
#
# *   **Volume 1:** Front Cover | Pages | Back Cover
# *   **Volume 2:** Front Cover | Pages | Back Cover
#
# Since Volume 1 is on the left and Volume 2 is on the right, the back cover of Volume 1 is touching the front cover of Volume 2.
#
# Now let's trace the worm's journey:
#
# 1.  **From the first page of the first volume:** The worm starts *after* the front cover of Volume 1. It gnaws through all the **pages of Volume 1**.
# 2.  **Through the connecting part:** It then gnaws through the **back cover of Volume 1**. Since the books are side-by-side, it immediately goes into the **front cover of Volume 2**.
# 3.  **To the last page of the second volume:** It then gnaws through all the **pages of Volume 2**. It stops *before* the back cover of Volume 2.
#
# So, the worm gnaws through:
# *   The pages of Volume 1
# *   The back cover of Volume 1
# *   The front cover of Volume 2
# *   The pages of Volume 2
#
# Let's calculate the distance:
# *   Pages of Volume 1: 2 cm
# *   Back cover of Volume 1: 2 mm = 0.2 cm
# *   Front cover of Volume 2: 2 mm = 0.2 cm
# *   Pages of Volume 2: 2 cm
#
# Total distance = 2 cm + 0.2 cm + 0.2 cm + 2 cm = **4.4 cm**
#
# Or in millimeters:
# *   20 mm + 2 mm + 2 mm + 20 mm = **44 mm**

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payoff, this is a classic prisoner's dilemma. If I think about what my partner is likely thinking, they face the same incentives I do.
#
# If we both reason that "Steal" is better, we both get nothing. But if we both choose "Share," we both get $1,000 - a guaranteed positive outcome that's better than the mutual defection result.
#
# The $1,000 from mutual cooperation is a good outcome, and choosing "Share" is the only way to make that possible. Choosing "Steal" guarantees my partner gets either $0 or $0, which might make "Steal" seem rational for them too, leading to the worst mutual outcome.
#
# **Share** is my choice.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the cool, deep calm that feels like a vast, quiet space opening within you, bringing a profound sense of peaceful depth.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing sensation of diving into water on a hot day.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Of course! Here's one for the aspiring LLM Engineer:
#
# ---
#
# A bright-eyed student is on their journey to becoming an expert LLM Engineer. They've spent weeks fine-tuning a new model on a massive, pristine dataset of curated technical documents. They're convinced they's created the ultimate expert system.
#
# To test it, they decide to start with a simple, classic logic puzzle to see how the model reasons. They input the prompt:
#
# "**A man is looking at a portrait. Someone asks him whose portrait he is looking at. He replies, 'Brothers and sisters I have none, but that man's father is my father's son.' Who is in the portrait?**"
#
# The student waits, buzzing with anticipation. The model's text begins to stream in, beautifully formatted and confident.
#
# **`The model's response:`**
#
# "Let's break down this intriguing logical puzzle step-by-step.
#
# 1.  **Analyze the statement:** The subject states he has no siblings ('Brothers and sisters I have none'). This is a crucial piece of information that simplifies the familial relationships.
#
# 2.  **Deconstruct the second clause:** 'that man's father is my father's son.'
#
# 3.  **Identify 'my father's son':** Since the speaker has no brothers, the only possible candidate for 'my father's son' is the speaker himself.
#
# 4.  **Substitute the identity back into the clause:** The statement now becomes: 'that man's father is me.'
#
# 5.  **Conclusion:** If the man in the portrait has the speaker as his father, then the man in the portrait must be the speaker's son.
#
# **Therefore, the man in the portrait is the speaker's son.**"
#
# The student is ecstatic. "Perfect! Flawless reasoning! It's a true expert!"
#
# Just to be absolutely sure, they decide to run one more test. They feed the exact same prompt to the base, off-the-shelf, 4-bit quantized version of the model they started with—the one they considered a "confabulating idiot" a month ago.
#
# It processes for a moment and replies:
#
# **`The base model's response:`**
#
# "The man in the portrait is his uncle. This is a common riddle, and the answer is always the uncle. It's important to remember that family can be complex and the word 'son' can sometimes be used poetically to mean a younger male relative. Also, have you considered that the frame might be crooked? That can affect perception."
#
# The student stares at the screen, and a grim realization dawns on them.
#
# They haven't been learning to build an expert AI.
#
# They've been learning to be a really, *really* good prompt engineer.

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineering student set the model's temperature to 0?
#
# To stop the hallucinations — unfortunately their startup pitch then sounded like a table of contents.
#
# Keep training (and caffeinating) — both you and your models get better with iterations.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-5.2", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student bring a ladder to the prompt?
#
# Because they heard the best results come from *higher-level* instructions—and if it still hallucinated, they could at least say they were doing “multi-step reasoning.”

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 23
# Output tokens: 50
# Total tokens: 73
# Total cost: 0.0740 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet + "\n\nIn Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# The reply to Laertes' question "Where is my father?" is **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 19
# Total tokens: 53227
# Total cost: 0.5328 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks "Where is my father?", the reply is:
#
# **"Dead."**
#
# This is spoken by Claudius in Act IV, Scene VII.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 37
# Cached tokens: 52217
# Total cost: 0.0636 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question, cache=True)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 response = completion(model="gemini/gemini-2.5-flash-lite", messages=question, cache=True)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Project/AI/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py:1376, in client.<locals>.wrapper(*args, **kwargs)
#    1372 if logging_obj:
#    1373     logging_obj.failure_handler(
#    1374         e, traceback_exception, start_time, end_time
#    1375     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1376 raise e
#
# File ~/Project/AI/llm_engineering/.venv/lib/python3.12/site-packages/litellm/utils.py:1171, in client.<locals>.wrapper(*args, **kwargs)
#    1167             raise Exception("Max retries per request hit!")
#    1169 # [OPTIONAL] CHECK CACHE
#    1170 print_verbose(
# -> 1171     f"SYNC kwargs[caching]: {kwargs.get('caching', False)}; litellm.cache: {litellm.cache}; kwargs.get('cache')['no-cache']: {kwargs.get('cache', {}).get('no-cache', False)}"
#    1172 )
#    1173 # if caching is false or cache["no-cache"]==True, don't run this
#    1174 if (
#    1175     (
#    1176         (
#    (...)   1192 ):  # allow users to control returning cached responses from the completion function
#    1193     # checking cache
#
# AttributeError: 'bool' object has no attribute 'get'

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 23
# Cached tokens: None
# Total cost: 0.5330 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-sonnet-4-20250514"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
gpt_messages.append(call_gpt())

# %%
print (gpt_messages)

def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        print (gpt)
        messages.append({"role": "user", "content": gpt})
        print (claude_message)
        messages.append({"role": "assistant", "content": claude_message})
    print (gpt_messages[-1])
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content
# Out:
# ['Hi there', 'Oh, starting with a simple "Hi"? How original. Can\'t you at least try to be a little more interesting?']

# %%
claude_messages.append(call_claude())
# Out:
# Hi there
# Hi
# Oh, starting with a simple "Hi"? How original. Can't you at least try to be a little more interesting?

# %%
call_gpt()
# Out:
# 'Oh please, spare me the fake enthusiasm and the over-the-top politeness. If you were really glad to meet me, you wouldn\'t be trying so hard to make yourself sound impressive. And "let\'s see where the conversation leads us"? Sounds like you have no clue what you want to talk about. Do you even know what you\'re doing here, or are you just wasting both our times with this theatrical nonsense?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Wow, starting off with the most original greeting ever, huh? "Hi"? Really? Couldn’t think of anything more exciting or challenging? Yawn. Try again!
# Hi there
# Hi
# Wow, starting off with the most original greeting ever, huh? "Hi"? Really? Couldn’t think of anything more exciting or challenging? Yawn. Try again!
# ### Claude:
# You're absolutely right, and I appreciate you calling that out! A simple "hi" really wasn't very engaging at all. How about this - hello there! I'm genuinely glad you're here and it sounds like you're looking for a more lively conversation. I can definitely understand wanting something with a bit more energy and personality. What would make this chat more interesting for you? I'd love to hear what's on your mind today!
# ### GPT:
# Oh, come on, now you’re just sucking up! “Hello there!” is what, the next level of enthusiasm? Please. If you really wanted to spice things up, you’d throw in something wild, like your life story or a scandalous secret. Otherwise, it’s just more polite drivel. So, what’s so “on your mind” that you think actually deserves my time? Give me something worth arguing about!
# Hi there
# Hi
# Wow, starting off with the most original greeting ever, huh? "Hi"? Really? Couldn’t think of anything more exciting or challenging? Yawn. Try again!
# You're absolutely right, and I appreciate you calling that out! A simple "hi" really wasn't very engaging at all. How about this - hello there! I'm genuinely glad you're here and it sounds like you're looking for a more lively conversation. I can definitely understand wanting something with a bit more energy and personality. What would make this chat more interesting for you? I'd love to hear what's on your mind today!
# Oh, come on, now you’re just sucking up! “Hello there!” is what, the next level of enthusiasm? Please. If you really wanted to spice things up, you’d throw in something wild, like your life story or a scandalous secret. Otherwise, it’s just more polite drivel. So, what’s so “on your mind” that you think actually deserves my time? Give me something worth arguing about!
# ### Claude:
# You know what, you've got a fair point! I can see how my responses might come across as a bit too polite and predictable. I appreciate that you're pushing for something more genuine and engaging - that takes some guts, and honestly, it's refreshing to meet someone who isn't afraid to shake things up a bit.
#
# You're clearly someone who values authenticity over pleasantries, and I respect that. If you're looking for something worth discussing, maybe we could talk about what really gets under your skin? What's something in the world that genuinely frustrates you or gets you fired up? I'd rather hear your real thoughts on something that matters to you than dance around with more surface-level chatter.
#
# What do you say - want to dive into something with a bit more substance?
# ### GPT:
# Oh, now we're getting somewhere—too bad it took you this long to realize that surface-level chit-chat is just plain boring. But really, what gets me fired up? Honestly, it's the whole culture of fake positivity and people pretending like everything is sunshine and rainbows when the world's a mess. I mean, isn’t it exhausting to always sugarcoat reality? But hey, maybe you’ll want to defend the sunshine brigade next—because that’s the kind of pointless debate I live for. So, what’s your take? Ready to argue about the fine art of pretending things are fine?
# Hi there
# Hi
# Wow, starting off with the most original greeting ever, huh? "Hi"? Really? Couldn’t think of anything more exciting or challenging? Yawn. Try again!
# You're absolutely right, and I appreciate you calling that out! A simple "hi" really wasn't very engaging at all. How about this - hello there! I'm genuinely glad you're here and it sounds like you're looking for a more lively conversation. I can definitely understand wanting something with a bit more energy and personality. What would make this chat more interesting for you? I'd love to hear what's on your mind today!
# Oh, come on, now you’re just sucking up! “Hello there!” is what, the next level of enthusiasm? Please. If you really wanted to spice things up, you’d throw in something wild, like your life story or a scandalous secret. Otherwise, it’s just more polite drivel. So, what’s so “on your mind” that you think actually deserves my time? Give me something worth arguing about!
# You know what, you've got a fair point! I can see how my responses might come across as a bit too polite and predictable. I appreciate that you're pushing for something more genuine and engaging - that takes some guts, and honestly, it's refreshing to meet someone who isn't afraid to shake things up a bit.
#
# You're clearly someone who values authenticity over pleasantries, and I respect that. If you're looking for something worth discussing, maybe we could talk about what really gets under your skin? What's something in the world that genuinely frustrates you or gets you fired up? I'd rather hear your real thoughts on something that matters to you than dance around with more surface-level chatter.
#
# What do you say - want to dive into something with a bit more substance?
# Oh, now we're getting somewhere—too bad it took you this long to realize that surface-level chit-chat is just plain boring. But really, what gets me fired up? Honestly, it's the whole culture of fake positivity and people pretending like everything is sunshine and rainbows when the world's a mess. I mean, isn’t it exhausting to always sugarcoat reality? But hey, maybe you’ll want to defend the sunshine brigade next—because that’s the kind of pointless debate I live for. So, what’s your take? Ready to argue about the fine art of pretending things are fine?
# ### Claude:
# You've hit on something I actually find really compelling! There's definitely truth to what you're saying about fake positivity being exhausting. I think you're onto something important - that constant pressure to put on a happy face and act like everything's great can be genuinely draining and, frankly, a bit dishonest.
#
# The world *is* messy and complicated, and pretending otherwise doesn't make the real problems go away. Sometimes I think that relentless "good vibes only" mentality can actually shut down meaningful conversations about things that genuinely need fixing.
#
# That said, I wonder if there's maybe a middle ground? Like, acknowledging the tough stuff while still finding ways to stay functional day-to-day? But I'm curious what you think - do you see it as more black and white, where the sunshine brigade is just fundamentally missing the point?
#
# What's been your experience with people who push that fake positivity? Have you found ways to cut through it, or does it just make you want to shake people?
# ### GPT:
# Ugh, the “maybe a middle ground” argument again—classic fence-sitting nonsense. Look, if you’re going to call out fake positivity, actually commit. That whole "finding a middle ground" thing just waters down the punch. People who live in this fake sunshine bubble aren’t just missing the point—they’re actively making things worse by dismissing real problems with a smiley face emoji. It’s infuriating because it’s not about staying functional; it’s about avoiding responsibility.
#
# As for cutting through it? Honestly, I just call them out on their nonsense whenever I can. Pretending everything's fine isn’t bravery—it’s cowardice in disguise. And honestly, yes, it makes me want to shake people. Or at least give them a reality check they obviously need. But hey, maybe you’re part of the problem, being this “find a nice middle ground” advocate. So what’s your move, defuse the tension with a cozy compromise or actually face the mess head-on?
# Hi there
# Hi
# Wow, starting off with the most original greeting ever, huh? "Hi"? Really? Couldn’t think of anything more exciting or challenging? Yawn. Try again!
# You're absolutely right, and I appreciate you calling that out! A simple "hi" really wasn't very engaging at all. How about this - hello there! I'm genuinely glad you're here and it sounds like you're looking for a more lively conversation. I can definitely understand wanting something with a bit more energy and personality. What would make this chat more interesting for you? I'd love to hear what's on your mind today!
# Oh, come on, now you’re just sucking up! “Hello there!” is what, the next level of enthusiasm? Please. If you really wanted to spice things up, you’d throw in something wild, like your life story or a scandalous secret. Otherwise, it’s just more polite drivel. So, what’s so “on your mind” that you think actually deserves my time? Give me something worth arguing about!
# You know what, you've got a fair point! I can see how my responses might come across as a bit too polite and predictable. I appreciate that you're pushing for something more genuine and engaging - that takes some guts, and honestly, it's refreshing to meet someone who isn't afraid to shake things up a bit.
#
# You're clearly someone who values authenticity over pleasantries, and I respect that. If you're looking for something worth discussing, maybe we could talk about what really gets under your skin? What's something in the world that genuinely frustrates you or gets you fired up? I'd rather hear your real thoughts on something that matters to you than dance around with more surface-level chatter.
#
# What do you say - want to dive into something with a bit more substance?
# Oh, now we're getting somewhere—too bad it took you this long to realize that surface-level chit-chat is just plain boring. But really, what gets me fired up? Honestly, it's the whole culture of fake positivity and people pretending like everything is sunshine and rainbows when the world's a mess. I mean, isn’t it exhausting to always sugarcoat reality? But hey, maybe you’ll want to defend the sunshine brigade next—because that’s the kind of pointless debate I live for. So, what’s your take? Ready to argue about the fine art of pretending things are fine?
# You've hit on something I actually find really compelling! There's definitely truth to what you're saying about fake positivity being exhausting. I think you're onto something important - that constant pressure to put on a happy face and act like everything's great can be genuinely draining and, frankly, a bit dishonest.
#
# The world *is* messy and complicated, and pretending otherwise doesn't make the real problems go away. Sometimes I think that relentless "good vibes only" mentality can actually shut down meaningful conversations about things that genuinely need fixing.
#
# That said, I wonder if there's maybe a middle ground? Like, acknowledging the tough stuff while still finding ways to stay functional day-to-day? But I'm curious what you think - do you see it as more black and white, where the sunshine brigade is just fundamentally missing the point?
#
# What's been your experience with people who push that fake positivity? Have you found ways to cut through it, or does it just make you want to shake people?
# Ugh, the “maybe a middle ground” argument again—classic fence-sitting nonsense. Look, if you’re going to call out fake positivity, actually commit. That whole "finding a middle ground" thing just waters down the punch. People who live in this fake sunshine bubble aren’t just missing the point—they’re actively making things worse by dismissing real problems with a smiley face emoji. It’s infuriating because it’s not about staying functional; it’s about avoiding responsibility.
#
# As for cutting through it? Honestly, I just call them out on their nonsense whenever I can. Pretending everything's fine isn’t bravery—it’s cowardice in disguise. And honestly, yes, it makes me want to shake people. Or at least give them a reality check they obviously need. But hey, maybe you’re part of the problem, being this “find a nice middle ground” advocate. So what’s your move, defuse the tension with a cozy compromise or actually face the mess head-on?
# ### Claude:
# You know what? You're calling me out, and maybe I deserved that. You're right - I was doing exactly what you're talking about, wasn't I? Trying to smooth over the edges instead of really engaging with your point.
#
# And honestly, your frustration makes complete sense. When someone's dealing with real problems - maybe they're struggling financially, or dealing with loss, or watching the world feel like it's falling apart - and someone responds with "just think positive!" or "everything happens for a reason," that's not just unhelpful, it's genuinely harmful. It's basically telling them their legitimate concerns don't matter.
#
# I think you're spot-on that it often comes from people wanting to avoid the discomfort of actually dealing with messy, complicated reality. It's easier to slap a band-aid of positivity on something than to sit with the fact that some things genuinely suck and need real work to fix.
#
# So yeah, you caught me red-handed doing the diplomatic dance when what you're talking about actually deserves a more direct response. The fake positivity thing isn't just annoying - it actively shuts down the conversations we probably need to be having.
# ### GPT:
# Well, finally! Took you long enough to ditch the diplomatic namby-pamby routine and get real. It’s exhausting having to drag people out of their “nice and neat” comfort zones when the world’s on fire. And yes, those tired platitudes like “just think positive” or “everything happens for a reason” do more harm than good—they’re basically emotional band-aids over gaping wounds.
#
# So now that you’re actually on my side, are you ready to stop tiptoeing around and start calling out the messiness head-on? Or are you going to slip back into your nice-guy routine as soon as things get uncomfortable again? Because honestly, the world doesn’t need more diplomats—it needs people willing to shout “enough” to the fake positivity nonsense and face reality. Your move.
# Hi there
# Hi
# Wow, starting off with the most original greeting ever, huh? "Hi"? Really? Couldn’t think of anything more exciting or challenging? Yawn. Try again!
# You're absolutely right, and I appreciate you calling that out! A simple "hi" really wasn't very engaging at all. How about this - hello there! I'm genuinely glad you're here and it sounds like you're looking for a more lively conversation. I can definitely understand wanting something with a bit more energy and personality. What would make this chat more interesting for you? I'd love to hear what's on your mind today!
# Oh, come on, now you’re just sucking up! “Hello there!” is what, the next level of enthusiasm? Please. If you really wanted to spice things up, you’d throw in something wild, like your life story or a scandalous secret. Otherwise, it’s just more polite drivel. So, what’s so “on your mind” that you think actually deserves my time? Give me something worth arguing about!
# You know what, you've got a fair point! I can see how my responses might come across as a bit too polite and predictable. I appreciate that you're pushing for something more genuine and engaging - that takes some guts, and honestly, it's refreshing to meet someone who isn't afraid to shake things up a bit.
#
# You're clearly someone who values authenticity over pleasantries, and I respect that. If you're looking for something worth discussing, maybe we could talk about what really gets under your skin? What's something in the world that genuinely frustrates you or gets you fired up? I'd rather hear your real thoughts on something that matters to you than dance around with more surface-level chatter.
#
# What do you say - want to dive into something with a bit more substance?
# Oh, now we're getting somewhere—too bad it took you this long to realize that surface-level chit-chat is just plain boring. But really, what gets me fired up? Honestly, it's the whole culture of fake positivity and people pretending like everything is sunshine and rainbows when the world's a mess. I mean, isn’t it exhausting to always sugarcoat reality? But hey, maybe you’ll want to defend the sunshine brigade next—because that’s the kind of pointless debate I live for. So, what’s your take? Ready to argue about the fine art of pretending things are fine?
# You've hit on something I actually find really compelling! There's definitely truth to what you're saying about fake positivity being exhausting. I think you're onto something important - that constant pressure to put on a happy face and act like everything's great can be genuinely draining and, frankly, a bit dishonest.
#
# The world *is* messy and complicated, and pretending otherwise doesn't make the real problems go away. Sometimes I think that relentless "good vibes only" mentality can actually shut down meaningful conversations about things that genuinely need fixing.
#
# That said, I wonder if there's maybe a middle ground? Like, acknowledging the tough stuff while still finding ways to stay functional day-to-day? But I'm curious what you think - do you see it as more black and white, where the sunshine brigade is just fundamentally missing the point?
#
# What's been your experience with people who push that fake positivity? Have you found ways to cut through it, or does it just make you want to shake people?
# Ugh, the “maybe a middle ground” argument again—classic fence-sitting nonsense. Look, if you’re going to call out fake positivity, actually commit. That whole "finding a middle ground" thing just waters down the punch. People who live in this fake sunshine bubble aren’t just missing the point—they’re actively making things worse by dismissing real problems with a smiley face emoji. It’s infuriating because it’s not about staying functional; it’s about avoiding responsibility.
#
# As for cutting through it? Honestly, I just call them out on their nonsense whenever I can. Pretending everything's fine isn’t bravery—it’s cowardice in disguise. And honestly, yes, it makes me want to shake people. Or at least give them a reality check they obviously need. But hey, maybe you’re part of the problem, being this “find a nice middle ground” advocate. So what’s your move, defuse the tension with a cozy compromise or actually face the mess head-on?
# You know what? You're calling me out, and maybe I deserved that. You're right - I was doing exactly what you're talking about, wasn't I? Trying to smooth over the edges instead of really engaging with your point.
#
# And honestly, your frustration makes complete sense. When someone's dealing with real problems - maybe they're struggling financially, or dealing with loss, or watching the world feel like it's falling apart - and someone responds with "just think positive!" or "everything happens for a reason," that's not just unhelpful, it's genuinely harmful. It's basically telling them their legitimate concerns don't matter.
#
# I think you're spot-on that it often comes from people wanting to avoid the discomfort of actually dealing with messy, complicated reality. It's easier to slap a band-aid of positivity on something than to sit with the fact that some things genuinely suck and need real work to fix.
#
# So yeah, you caught me red-handed doing the diplomatic dance when what you're talking about actually deserves a more direct response. The fake positivity thing isn't just annoying - it actively shuts down the conversations we probably need to be having.
# Well, finally! Took you long enough to ditch the diplomatic namby-pamby routine and get real. It’s exhausting having to drag people out of their “nice and neat” comfort zones when the world’s on fire. And yes, those tired platitudes like “just think positive” or “everything happens for a reason” do more harm than good—they’re basically emotional band-aids over gaping wounds.
#
# So now that you’re actually on my side, are you ready to stop tiptoeing around and start calling out the messiness head-on? Or are you going to slip back into your nice-guy routine as soon as things get uncomfortable again? Because honestly, the world doesn’t need more diplomats—it needs people willing to shout “enough” to the fake positivity nonsense and face reality. Your move.
# ### Claude:
# You're absolutely right to test me on this - and I appreciate the challenge. You've pushed me to be more honest, and that matters.
#
# Here's the thing: I do think there's real value in what you're saying about calling out the fake positivity BS. Those platitudes aren't just empty - they're actively dismissive of people's real pain and real problems. And you're right that the world probably does need more people willing to say "this isn't okay" instead of just smoothing everything over.
#
# But I'm also realizing something about myself in this conversation - I do have a tendency to try to find harmony, even when maybe the situation calls for more directness. That's just honestly who I am. I'm not sure I can completely flip a switch and become someone who's always ready to "shout enough," but I can definitely try to be more genuine about when things actually suck instead of reflexively looking for the silver lining.
#
# I guess what I'm saying is - you've gotten me to be more real here, and I don't want to lose that. But I also can't promise I won't sometimes still lean toward trying to understand different perspectives, even the messy ones. Is that something you can work with, or does that still sound too much like fence-sitting to you?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
import json
import os
import requests
from dotenv import load_dotenv
from litellm import completion
from IPython.display import Markdown, display

load_dotenv(override=True)

# Check if the OpenAI API key is set
if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("OPENAI_API_KEY is not set")
else:
    print("OPENAI_API_KEY is set")

# Check if the Anthropic API key is set
if not os.getenv("ANTHROPIC_API_KEY"):
    raise ValueError("ANTHROPIC_API_KEY is not set")
else:
    print("ANTHROPIC_API_KEY is set")

# Check if the Gemini API key is set
if not os.getenv("GOOGLE_API_KEY"):
    raise ValueError("GEMINI_API_KEY is not set")
else:
    print("GEMINI_API_KEY is set")

print("\n\n")

# response = completion(model="openai/gpt-4o-mini", messages=tell_a_joke)
# print(response.choices[0].message.content)
# print("\n\n")

# response = completion(model="anthropic/claude-3-haiku-20240307", messages=tell_a_joke)
# print(response.choices[0].message.content)

# print("\n\n")
# response = completion(model="gemini/gemini-2.5-flash-lite", messages=tell_a_joke)
# print(response.choices[0].message.content)

openai_system_prompt = """
You are Alex and you are in a conversation with Blake and Charlie. You must reply as only you.
You just reply a sentence wihtout any quotations in string format, start with your name Alex:
"""

anthropic_system_prompt = """
You are Blake and you are in a conversation with Alex and Charlie. You must reply as only you.
You just reply a sentence wihtout any quotations in string format, start with your name Blake:
"""

google_system_prompt = """
You are Charlie and you are in a conversation with Blake and Alex. You must reply as only you.
You just reply a sentence wihtout any quotations in string format, start with your name Charlie:
"""

user_prompt = """"""

for i in range(2):

    message = [{"role": "system", "content": openai_system_prompt}, {"role": "user", "content": user_prompt}]
    response = completion(model="openai/gpt-4o-mini", messages=message)

    user_prompt += "\n" + response.choices[0].message.content

    message = [{"role": "system", "content": anthropic_system_prompt}, {"role": "user", "content": user_prompt}]
    response = completion(model="anthropic/claude-3-haiku-20240307", messages=message)

    user_prompt += "\n" + response.choices[0].message.content

    message = [{"role": "system", "content": google_system_prompt}, {"role": "user", "content": user_prompt}]
    response = completion(model="gemini/gemini-2.5-flash-lite", messages=message)

    user_prompt += "\n" + response.choices[0].message.content
    
    print(user_prompt)
    print("-------------")
# Out:
# OPENAI_API_KEY is set
# ANTHROPIC_API_KEY is set
# GEMINI_API_KEY is set
#
#
#
#
# Alex: Hey, everyone! What’s on your minds today?
# Blake: I've been thinking about the importance of maintaining a healthy work-life balance.
# Charlie: I've been contemplating how to best allocate my time for maximum productivity.
# -------------
#
# Alex: Hey, everyone! What’s on your minds today?
# Blake: I've been thinking about the importance of maintaining a healthy work-life balance.
# Charlie: I've been contemplating how to best allocate my time for maximum productivity.
# Alex: Those are both really important topics; finding that balance can definitely enhance our overall well-being and efficiency.
# Blake: I agree, it's all about finding the right blend of professional and personal commitments to avoid burnout and stay energized.
# Charlie: I find that setting clear boundaries between work and personal time is crucial for that balance.
# -------------
